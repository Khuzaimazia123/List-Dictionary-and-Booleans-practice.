# %%
print (" I like only 4 toys and they are ...")
toys = ["cars","football","LEGO","play dough"]
print ("toys list:",toys)
print ("now I like 5 toys and they are...")
toys.append("bouncy ball")
print ("updated toys list:",toys)
print ("But my favourite toy is...")
print ("second toy:",toys[1])
print ("let me show you my profile")
person = {
"name" : "Khuzaima",
"age" : 11,
"city" : "Rawalpindi"}
print ("person info:",person)
print ("name:",person["name"])
person["second name"] = "Zia"
print ("Updated person info:",person)
fan_on =True
fan_off=False
person["second name"] ="Zia"
# Out:
#  I like only 4 toys and they are ...
# toys list: ['cars', 'football', 'LEGO', 'play dough']
# now I like 5 toys and they are...
# updated toys list: ['cars', 'football', 'LEGO', 'play dough', 'bouncy ball']
# But my favourite toy is...
# second toy: football
# let me show you my profile
# person info: {'name': 'Khuzaima', 'age': 11, 'city': 'Rawalpindi'}
# name: Khuzaima
# Updated person info: {'name': 'Khuzaima', 'age': 11, 'city': 'Rawalpindi', 'second name': 'Zia'}
